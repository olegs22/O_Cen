# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sb
import corner as corner 
sb.set_style('white')
# %config InlineBackend.figure_format = 'retina'

# %%
data14 = np.loadtxt('chain_14.dat')
data11 = np.loadtxt('chain_11.dat')

# %%
plt.figure()
plt.plot(data14[:,0]);
plt.figure()
plt.plot(data14[:,1]);
plt.figure()
plt.plot(data14[:,2]);

# %%
plt.figure()
plt.plot(data11[:,0]);
plt.figure()
plt.plot(data11[:,1]);
plt.figure()
plt.plot(data11[:,2]);

# %%
fig = corner.corner(data14,bins=50,plot_datapoints=False,smooth=2., 
                    smooth1d=2.,levels=(1.-np.exp(-0.5),1.-np.exp(-2.)),quantiles=[.025,0.5,0.975],show_titles=True);

# %%
fig1 = corner.corner(data11,bins=50,plot_datapoints=False,smooth=2., 
                    smooth1d=2.,levels=(1.-np.exp(-0.5),1.-np.exp(-2.)),quantiles=[.025,0.5,0.975],show_titles=True);
